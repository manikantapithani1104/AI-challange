# %%
text = "Python is easy to learn. Python is powerful and Python is popular."

print(text)
# Out:
# Python is easy to learn. Python is powerful and Python is popular.

# %%
text = text.lower()

print(text)
# Out:
# python is easy to learn. python is powerful and python is popular.

# %%
import string

text = text.translate(str.maketrans('', '', string.punctuation))

print(text)
# Out:
# python is easy to learn python is powerful and python is popular

# %%
words = text.split()

print(words)
# Out:
# ['python', 'is', 'easy', 'to', 'learn', 'python', 'is', 'powerful', 'and', 'python', 'is', 'popular']

# %%
from collections import Counter

word_count = Counter(words)

print(word_count)
# Out:
# Counter({'python': 3, 'is': 3, 'easy': 1, 'to': 1, 'learn': 1, 'powerful': 1, 'and': 1, 'popular': 1})

# %%
for word, count in word_count.items():
    print(word, ":", count)
# Out:
# python : 3
# is : 3
# easy : 1
# to : 1
# learn : 1
# powerful : 1
# and : 1
# popular : 1

# %%
import string
from collections import Counter

text = "Python is easy to learn. Python is powerful and Python is popular."

# Convert text to lowercase
text = text.lower()

# Remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))

# Split text into words
words = text.split()

# Count word frequency
word_count = Counter(words)

# Display word frequency
print("Word Frequency:")
for word, count in word_count.items():
    print(word, ":", count)
# Out:
# Word Frequency:
# python : 3
# is : 3
# easy : 1
# to : 1
# learn : 1
# powerful : 1
# and : 1
# popular : 1
